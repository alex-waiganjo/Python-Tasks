# %%
import pandas as pd
import requests

# %%
url = "https://dummyjson.com/users"
data = requests.get(url)
data.status_code
# Out:
# 200

# %%
user_data = data.json()
user_data

# %%
nom_data = pd.json_normalize(user_data["users"])
nom_data
# Out:
#     id  firstName   lastName maidenName  age  gender  \
# 0    1      Emily    Johnson      Smith   29  female
# 1    2    Michael   Williams              36    male
# 2    3     Sophia      Brown              43  female
# 3    4      James      Davis              46    male
# 4    5       Emma     Miller    Johnson   31  female
# 5    6     Olivia     Wilson              23  female
# 6    7  Alexander      Jones              39    male
# 7    8        Ava     Taylor              28  female
# 8    9      Ethan   Martinez              34    male
# 9   10   Isabella   Anderson      Davis   32  female
# 10  11       Liam     Garcia              30    male
# 11  12        Mia  Rodriguez              25  female
# 12  13       Noah  Hernandez              41    male
# 13  14  Charlotte      Lopez   Martinez   37  female
# 14  15    William   Gonzalez              33    male
# 15  16      Avery      Perez              26  female
# 16  17     Evelyn    Sanchez              38  female
# ...

# %%
nom_data.columns = nom_data.columns.str.replace("company.address.", "", regex=False)

# %%
nom_data.columns
# Out:
# Index(['id', 'firstName', 'lastName', 'maidenName', 'age', 'gender', 'email',
#        'phone', 'username', 'password', 'birthDate', 'image', 'bloodGroup',
#        'height', 'weight', 'eyeColor', 'ip', 'macAddress', 'university', 'ein',
#        'ssn', 'userAgent', 'role', 'hair.color', 'hair.type',
#        'address.address', 'address.city', 'address.state', 'address.stateCode',
#        'address.postalCode', 'address.coordinates.lat',
#        'address.coordinates.lng', 'address.country', 'bank.cardExpire',
#        'bank.cardNumber', 'bank.cardType', 'bank.currency', 'bank.iban',
#        'company.department', 'company.name', 'company.title', 'address',
#        'city', 'state', 'stateCode', 'postalCode', 'coordinates.lat',
#        'coordinates.lng', 'country', 'crypto.coin', 'crypto.wallet',
#        'crypto.network'],
#       dtype='str')

# %%
nom_data
# Out:
#     id  firstName   lastName maidenName  age  gender  \
# 0    1      Emily    Johnson      Smith   29  female
# 1    2    Michael   Williams              36    male
# 2    3     Sophia      Brown              43  female
# 3    4      James      Davis              46    male
# 4    5       Emma     Miller    Johnson   31  female
# 5    6     Olivia     Wilson              23  female
# 6    7  Alexander      Jones              39    male
# 7    8        Ava     Taylor              28  female
# 8    9      Ethan   Martinez              34    male
# 9   10   Isabella   Anderson      Davis   32  female
# 10  11       Liam     Garcia              30    male
# 11  12        Mia  Rodriguez              25  female
# 12  13       Noah  Hernandez              41    male
# 13  14  Charlotte      Lopez   Martinez   37  female
# 14  15    William   Gonzalez              33    male
# 15  16      Avery      Perez              26  female
# 16  17     Evelyn    Sanchez              38  female
# ...

# %%
ff = pd.DataFrame(nom_data)
ff
# Out:
#                                                users  total  skip  limit
# 0  [{'id': 1, 'firstName': 'Emily', 'lastName': '...    208     0     30

# %%
user_data["users"]
# Out:
# [{'id': 1,
#   'firstName': 'Emily',
#   'lastName': 'Johnson',
#   'maidenName': 'Smith',
#   'age': 29,
#   'gender': 'female',
#   'email': 'emily.johnson@x.dummyjson.com',
#   'phone': '+81 965-431-3024',
#   'username': 'emilys',
#   'password': 'emilyspass',
#   'birthDate': '1996-5-30',
#   'image': 'https://dummyjson.com/icon/emilys/128',
#   'bloodGroup': 'O-',
#   'height': 193.24,
#   'weight': 63.16,
#   'eyeColor': 'Green',
#   'hair': {'color': 'Brown', 'type': 'Curly'},
#   'ip': '42.48.100.32',
#   'address': {'address': '626 Main Street',
#    'city': 'Phoenix',
#    'state': 'Mississippi',
#    'stateCode': 'MS',
#    'postalCode': '29112',
#    'coordinates': {'lat': -77.16213, 'lng': -92.084824},
#    'country': 'United States'},
#   'macAddress': '47:fa:41:18:ec:eb',
#   'university': 'University of Wisconsin--Madison',
#   'bank': {'cardExpire': '05/28',
#    'cardNumber': '3693233511855044',
#    'cardType': 'Diners Club International',
#    'currency': 'GBP',
# ...

# %%
len(user_data["users"])
# Out:
# 30

# %%
user_data["users"]
# Out:
# [{'id': 1,
#   'firstName': 'Emily',
#   'lastName': 'Johnson',
#   'maidenName': 'Smith',
#   'age': 29,
#   'gender': 'female',
#   'email': 'emily.johnson@x.dummyjson.com',
#   'phone': '+81 965-431-3024',
#   'username': 'emilys',
#   'password': 'emilyspass',
#   'birthDate': '1996-5-30',
#   'image': 'https://dummyjson.com/icon/emilys/128',
#   'bloodGroup': 'O-',
#   'height': 193.24,
#   'weight': 63.16,
#   'eyeColor': 'Green',
#   'hair': {'color': 'Brown', 'type': 'Curly'},
#   'ip': '42.48.100.32',
#   'address': {'address': '626 Main Street',
#    'city': 'Phoenix',
#    'state': 'Mississippi',
#    'stateCode': 'MS',
#    'postalCode': '29112',
#    'coordinates': {'lat': -77.16213, 'lng': -92.084824},
#    'country': 'United States'},
#   'macAddress': '47:fa:41:18:ec:eb',
#   'university': 'University of Wisconsin--Madison',
#   'bank': {'cardExpire': '05/28',
#    'cardNumber': '3693233511855044',
#    'cardType': 'Diners Club International',
#    'currency': 'GBP',
# ...

# %%
item_data = pd.DataFrame(user_data["users"])
item_data
# Out:
#     id  firstName   lastName maidenName  age  gender  \
# 0    1      Emily    Johnson      Smith   29  female
# 1    2    Michael   Williams              36    male
# 2    3     Sophia      Brown              43  female
# 3    4      James      Davis              46    male
# 4    5       Emma     Miller    Johnson   31  female
# 5    6     Olivia     Wilson              23  female
# 6    7  Alexander      Jones              39    male
# 7    8        Ava     Taylor              28  female
# 8    9      Ethan   Martinez              34    male
# 9   10   Isabella   Anderson      Davis   32  female
# 10  11       Liam     Garcia              30    male
# 11  12        Mia  Rodriguez              25  female
# 12  13       Noah  Hernandez              41    male
# 13  14  Charlotte      Lopez   Martinez   37  female
# 14  15    William   Gonzalez              33    male
# 15  16      Avery      Perez              26  female
# 16  17     Evelyn    Sanchez              38  female
# ...
