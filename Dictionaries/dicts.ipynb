# %%
# Dictionaries
user = {
    "first_name": "John",
    "last_name": "Doe",
    "age":33,
    "gender": "Male",
    "country": "Kenya",
    "emp_status": "Employed",
    "salary": 350000,
    "marital_status": "Married"
}

user["first_name"] = "Philip"
user.get("salary")
# Out:
# 350000

# %%
user.keys()
# Out:
# dict_keys(['first_name', 'last_name', 'age', 'gender', 'country', 'emp_status', 'salary', 'marital_status'])

# %%
user.values()
# Out:
# dict_values(['Philip', 'Doe', 33, 'Male', 'Kenya', 'Employed', 350000, 'Married'])

# %%
user.items()
# Out:
# dict_items([('pension', 'is_pensionable')])

# %%
user
# Out:
# {'first_name': 'Philip',
#  'last_name': 'Doe',
#  'age': 33,
#  'gender': 'Male',
#  'country': 'Kenya',
#  'emp_status': 'Employed',
#  'salary': 350000,
#  'marital_status': 'Married'}

# %%
user["pension"] = "is_pensionable"
user
# Out:
# {'first_name': 'Philip',
#  'last_name': 'Doe',
#  'age': 33,
#  'gender': 'Male',
#  'country': 'Kenya',
#  'emp_status': 'Employed',
#  'salary': 350000,
#  'marital_status': 'Married',
#  'pension': 'is_pensionable'}

# %%
user.pop("pension")
user
# Out:
# {'first_name': 'Philip',
#  'last_name': 'Doe',
#  'age': 33,
#  'gender': 'Male',
#  'country': 'Kenya',
#  'emp_status': 'Employed',
#  'salary': 350000,
#  'marital_status': 'Married'}

# %%
user.popitem()
user
# Out:
# {'first_name': 'Philip',
#  'last_name': 'Doe',
#  'age': 33,
#  'gender': 'Male',
#  'country': 'Kenya',
#  'emp_status': 'Employed',
#  'salary': 350000}

# %%
del user["salary"]
user
# Out:
# {'first_name': 'Philip',
#  'last_name': 'Doe',
#  'age': 33,
#  'gender': 'Male',
#  'country': 'Kenya',
#  'emp_status': 'Employed'}

# %%
# Looping over the whole dict
for key, value in user.items():
    print(f"{key}, {value}")
# Out:
# first_name, Philip
# last_name, Doe
# age, 33
# gender, Male
# country, Kenya
# emp_status, Employed

# %%
# Copying a Dictionary
user_1 = user.copy()
user_1
# Out:
# {'first_name': 'Philip',
#  'last_name': 'Doe',
#  'age': 33,
#  'gender': 'Male',
#  'country': 'Kenya',
#  'emp_status': 'Employed'}

# %%
# Nested Dictionaries
all_employees = [
    {
        "first_name": "Alex",
        "last_name" : "Jones",
        "age":33,
        "job" : "software engineer",
        "country": "Kenya",
        "emp_status": "Employed"  
    },
    {
        "first_name": "Jane",
        "last_name" : "Kimberly",
        "age":23,
        "job" : "Devops engineer",
        "country": "US",
        "emp_status": "Employed"  
    },
    {
        "first_name": "Mathew",
        "last_name" : "Kabila",
        "age":25,
        "job" : "Product Manager",
        "country": "Uganda",
        "emp_status": "Self-Employed"  
    },
    {
        "first_name": "Pauline",
        "last_name" : "Khoza",
        "age":30,
        "job" : "Human Resource Manager",
        "country": "South Africa",
        "emp_status": "Unemployed"  
    },
    {
        "first_name": "Zebedee",
        "last_name" : "JAdemola",
        "age":35,
        "job" : "CTO",
        "country": "Nigeria",
        "emp_status": "Employed"  
    },
    {
        "first_name": "Cillian",
        "last_name" : "Murphy",
        "age":17,
        "job" : "CEO",
        "country": "UK",
        "emp_status": "Self-Employed"  
    }
]

# %%
all_employees
# Out:
# [{'first_name': 'Alex',
#   'last_name': 'Jones',
#   'age': 33,
#   'job': 'software engineer',
#   'country': 'Kenya',
#   'emp_status': 'Employed'},
#  {'first_name': 'Jane',
#   'last_name': 'Kimberly',
#   'age': 23,
#   'job': 'Devops engineer',
#   'country': 'US',
#   'emp_status': 'Employed'},
#  {'first_name': 'Mathew',
#   'last_name': 'Kabila',
#   'age': 25,
#   'job': 'Product Manager',
#   'country': 'Uganda',
#   'emp_status': 'Self-Employed'},
#  {'first_name': 'Pauline',
#   'last_name': 'Khoza',
#   'age': 30,
#   'job': 'Human Resource Manager',
#   'country': 'South Africa',
#   'emp_status': 'Unemployed'},
#  {'first_name': 'Zebedee',
#   'last_name': 'JAdemola',
#   'age': 35,
#   'job': 'CTO',
#   'country': 'Nigeria',
#   'emp_status': 'Employed'},
#  {'first_name': 'Cillian',
#   'last_name': 'Murphy',
#   'age': 17,
#   'job': 'CEO',
#   'country': 'UK',
#   'emp_status': 'Self-Employed'}]

# %%
# Loop through the elements in the list
for emps in range(len(all_employees)):
    print(emps,all_employees[emps])
# Out:
# 0 {'first_name': 'Alex', 'last_name': 'Jones', 'age': 33, 'job': 'software engineer', 'country': 'Kenya', 'emp_status': 'Employed'}
# 1 {'first_name': 'Jane', 'last_name': 'Kimberly', 'age': 23, 'job': 'Devops engineer', 'country': 'US', 'emp_status': 'Employed'}
# 2 {'first_name': 'Mathew', 'last_name': 'Kabila', 'age': 25, 'job': 'Product Manager', 'country': 'Uganda', 'emp_status': 'Self-Employed'}
# 3 {'first_name': 'Pauline', 'last_name': 'Khoza', 'age': 30, 'job': 'Human Resource Manager', 'country': 'South Africa', 'emp_status': 'Unemployed'}
# 4 {'first_name': 'Zebedee', 'last_name': 'JAdemola', 'age': 35, 'job': 'CTO', 'country': 'Nigeria', 'emp_status': 'Employed'}
# 5 {'first_name': 'Cillian', 'last_name': 'Murphy', 'age': 17, 'job': 'CEO', 'country': 'UK', 'emp_status': 'Self-Employed'}
